# %% [markdown]
# <a href="https://colab.research.google.com/github/PrakharAgrawal031/Machine-Learning-Practice-Projects/blob/main/seaborn_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
tips = sns.load_dataset('tips')
sns.set_theme()
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', hue = 'smoker', style = 'smoker', col = 'time'  )

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
loc ='/content/sample_data/california_housing_test.csv'
loc_train = '/content/sample_data/california_housing_train.csv'

# %%
housing = pd.read_csv(loc)
housing_train = pd.read_csv(loc_train)

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
features = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income']

# %%
val_y = housing.median_house_value
train_y = housing_train.median_house_value
val_X = housing[features]
train_X = housing_train[features]

# %%
val_X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income
# 0      1537.0       606.0         6.6085
# 1       809.0       277.0         3.5990
# 2      1484.0       495.0         5.7934
# 3        49.0        11.0         6.1359
# 4       850.0       237.0         2.9375

# %%
def predict(train_X, train_y, val_X, val_y):
  model = RandomForestRegressor(n_estimators=100, random_state=0)
  model.fit(train_X,train_y)
  preds = model.predict(val_X)
  return mean_absolute_error(val_y, preds)

# %%
for x in [10,100,500]:
  print(x, ' = ', predict(train_X, train_y, val_X, val_y))
# Out:
# 10  =  32057.824669999998
# 100  =  32057.824669999998
# 500  =  32057.824669999998

# %%
# Out:
# 0
